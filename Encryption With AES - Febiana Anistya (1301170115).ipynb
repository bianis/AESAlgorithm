# %% [markdown]
# # Enkripsi AES

# %% [markdown]
# <img src="Steps.jpg">

# %% [markdown]
# <img src="Steps-detailed.jpg">

# %% [markdown]
# Task Tugas Besar
# - melakukan enkripsi AES dengan kunci buatan sendiri dan tabel Mix Column buatan sendiri
# - dikumpulkan saat hari H UAS kemungkinan tanggal 14 Mei 2020

# %% [markdown]
# # Initial Round + STEP 4 - AddRoundKey

# %%
def add_round_key(A, k):
    for i in range(4):
        for j in range(4):
            A[i][j] ^= k[i][j]

# %% [markdown]
# # STEP 1 - SubBytes

# %%
def sub_bytes(s):
    for i in range(4):
        for j in range(4):
            s[i][j] = s_box[s[i][j]]

# %% [markdown]
# # STEP 2 - ShiftRows

# %%
def shift_rows(s):
    s[1][0], s[1][1], s[1][2], s[1][3] = s[1][1], s[1][2], s[1][3], s[1][0]
    s[2][0], s[2][1], s[2][2], s[2][3] = s[2][2], s[2][3], s[2][0], s[2][1]
    s[3][0], s[3][1], s[3][2], s[3][3] = s[3][3], s[3][0], s[3][1], s[3][2]

# %% [markdown]
# # STEP 3 - MixColoumns

# %%
def mixColumn(s):
#     matrixCustom = [[0x02, 0x01, 0x02, 0x01],
#                     [0x02, 0x01, 0x01, 0x01],
#                     [0x01, 0x02, 0x02, 0x01],
#                     [0x02, 0x03, 0x03, 0x02]]
#     matrixCustom = [[0x02, 0x03, 0x01, 0x01],
#                     [0x01, 0x02, 0x03, 0x01],
#                     [0x01, 0x01, 0x02, 0x03],
#                     [0x03, 0x01, 0x01, 0x02]]
    
    matrixCustom = [[0x01, 0x01, 0x02, 0x03],
                    [0x03, 0x01, 0x01, 0x02],
                    [0x02, 0x03, 0x01, 0x01],
                    [0x01, 0x02, 0x03, 0x01]]
    
    for r in range(len(s)):
        for d in range(len(s[r])):
            s[r][d] = bin(s[r][d])[2:].zfill(8)
        
    hasil = []
    for q in range(4):
        temp = []
        temp.append(s[0][q]) 
        temp.append(s[1][q])
        temp.append(s[2][q])
        temp.append(s[3][q])
        for r in range(4):
            newcol = []
            j = 0
            for i in matrixCustom[r]:
                if i == 2:
                    lmix = list(temp[j])
                    lmix[0] = lmix[1]
                    lmix[1] = lmix[2]
                    lmix[2] = lmix[3]
                    lmix[3] = lmix[4]
                    lmix[4] = lmix[5]
                    lmix[5] = lmix[6]
                    lmix[6] = lmix[7]
                    lmix[7] = '0'
                    o = ''.join(lmix)
                    if temp[j][0] == '1':
                        newcol.append(int(o,2) ^ 0x1b)
                    else:
                        newcol.append(int(o,2))
                elif i == 3:
                    p = int(temp[j],2)
                    lmix = list(temp[j])
                    lmix[0] = lmix[1]
                    lmix[1] = lmix[2]
                    lmix[2] = lmix[3]
                    lmix[3] = lmix[4]
                    lmix[4] = lmix[5]
                    lmix[5] = lmix[6]
                    lmix[6] = lmix[7]
                    lmix[7] = '0'
                    o = ''.join(lmix)
                    if temp[j][0] == '1':
                        newcol.append(int(o,2) ^ 0x1b ^ p)
                    else:
                        newcol.append(int(o,2) ^ p)
                else:
                    newcol.append(int(temp[j],2))
                j += 1
#             for b in newcol:
#                 print(hex(b)[2:], end=' ')
#             print()
            hasil.append(newcol[0] ^ newcol[1] ^ newcol[2] ^ newcol[3])
#         print()
    c = 0
    for i in range(4):
        for o in range(4):
            s[o][i] = hasil[c]
            c += 1

# %%
def keySchedule(key, idRound):
    temp = []
    temp.append(key[1][3])
    temp.append(key[2][3])
    temp.append(key[3][3])
    temp.append(key[0][3])

    temp2 = []
    temp2.append(key[0][0])
    temp2.append(key[1][0])
    temp2.append(key[2][0])
    temp2.append(key[3][0])
    
    RCon = [[0x01, 0x00, 0x00, 0x00],
            [0x02, 0x00, 0x00, 0x00],
            [0x04, 0x00, 0x00, 0x00],
            [0x08, 0x00, 0x00, 0x00],
            [0x10, 0x00, 0x00, 0x00],
            [0x20, 0x00, 0x00, 0x00],
            [0x40, 0x00, 0x00, 0x00],
            [0x80, 0x00, 0x00, 0x00],
            [0x1b, 0x00, 0x00, 0x00],
            [0x36, 0x00, 0x00, 0x00]]

    for i in range(4):
        temp[i] = s_box[temp[i]]

    n = 0
    c1 = []
    for i in temp:
        c1.append(i ^ RCon[idRound][n] ^ temp2[n])
        n += 1
    
    c2 = []
    for e in range(4):
        c2.append(key[e][1] ^ c1[e])

    c3 = []
    for e in range(4):
        c3.append(key[e][2] ^ c2[e])

    c4 = []
    for e in range(4):
        c4.append(key[e][3] ^ c3[e])

    newkey = []
    for i in range(4):
        newkey.append([c1[i], c2[i], c3[i], c4[i]])

    c = 0    
    for i in range(4):
        for o in range(4):
            key[o][i] = newkey[o][i]
            c += 1
    return key

# %%
s_box = (
    ,
)

# %% [markdown]
# # PROSES ENKRIPSI

# %%
def printM(s):
    print('\n'.join([''.join(['{:4}'.format(hex(item)[2:]) for item in row]) 
      for row in s]))

# %%
def printbin(s):
    for r in s:
        print(r)

# %%
import copy
print('ENKRIPSI AES')
A = [[0x73, 0x61, 0x79, 0x61],
     [0x73, 0x75, 0x6b, 0x61],
     [0x6d, 0x61, 0x69, 0x6e],
     [0x61, 0x6c, 0x67, 0x6f]]

# A = [[0x32, 0x88, 0x31, 0xe0],
#      [0x43, 0x5a, 0x31, 0x37],
#      [0xf6, 0x30, 0x98, 0x07],
#      [0xa8, 0x8d, 0xa2, 0x34]]

K = [[0x62, 0x75, 0x61, 0x74],
     [0x6b, 0x65, 0x79, 0x73],
     [0x6c, 0x61, 0x67, 0x69],
     [0x64, 0x69, 0x72, 0x69]]

# K = [[0x2b, 0x28, 0xab, 0x09],
#      [0x7e, 0xae, 0xf7, 0xcf],
#      [0x15, 0xd2, 0x15, 0x4f],
#      [0x16, 0xa6, 0x88, 0x3c]]

originalKey = copy.deepcopy(K)

expkey = []

print('============================')
print('Round 0')
print('============================')
printM(A)
print()
print('Add Round Key')
add_round_key(A, K)
printM(A)
print()

for i in range(9):
    print('============================')
    print('Round ',i+1)
    print('============================')
    print()
    print('R',i+1,'Step 1 - Sub Bytes')
    print('----------------------')
    sub_bytes(A)
    printM(A)
    print()
    shift_rows(A)
    print('R',i+1,'Step 2 - Shift Rows')
    print('----------------------')
    printM(A)
    print()

    print('R',i+1,'Step 3 - Mix Column')
    print('----------------------')
    mixColumn(A)
    printM(A)
    print()
    K = keySchedule(K, i)
    expkey.append(copy.deepcopy(K))
    print('R',i+1,'Step 4 - Add Round Key')
    print('----------------------')
    printM(K)
    print()
    add_round_key(A, K)
    printM(A)
    print()
    
print('============================')
print('Round 10')
print('============================')
printM(A)
print()
print('R 10 Step 1 - Sub Bytes')
print('----------------------')
sub_bytes(A)
printM(A)
print()
print('R 10 Step 2 - Shift Rows')
print('----------------------')
shift_rows(A)
printM(A)
print()
print('R 10 Step 4 - Add Round Key')
print('----------------------')
K = keySchedule(K,9)
expkey.append(copy.deepcopy(K))
printM(K)
print()
add_round_key(A, K)
printM(A)
print()
# Out:
# ENKRIPSI AES
# ...
# Round 0
# ...
# 73  61  79  61
# 73  75  6b  61
# 6d  61  69  6e
# 61  6c  67  6f
#
# Add Round Key
# 11  14  18  15
# 18  10  12  12
# 1   0   e   7
# 5   5   15  6
#
# ...
# Round  1
# ...
#
# R 1 Step 1 - Sub Bytes
# ----------------------
# 82  fa  ad  59
# ad  ca  c9  c9
# 7c  63  ab  c5
# 6b  6b  59  6f
#
# R 1 Step 2 - Shift Rows
# ----------------------
# 82  fa  ad  59
# ca  c9  c9  ad
# ab  c5  7c  63
# 6f  6b  6b  59
#
# R 1 Step 3 - Mix Column
# ----------------------
# b4  1f  21  d9
# 22  cf  8f  97
# 9e  1   16  64
# 84  4c  cb  e4
#
# R 1 Step 4 - Add Round Key
# ----------------------
# ec  99  f8  8c
# 92  f7  8e  fd
# 95  f4  93  fa
# f6  9f  ed  84
#
# 58  86  d9  55
# b0  38  1   6a
# b   f5  85  9e
# 72  d3  26  60
#
# ...
# Round  2
# ...
#
# R 2 Step 1 - Sub Bytes
# ----------------------
# 6a  44  35  fc
# e7  7   7c  2
# 2b  e6  97  b
# 40  66  f7  d0
#
# R 2 Step 2 - Shift Rows
# ----------------------
# 6a  44  35  fc
# 7   7c  2   e7
# 97  b   2b  e6
# d0  40  66  f7
#
# ...

# %%
print('Hasil Ciphertext')
print('============================')
for k in range(4):
    for j in range(4):
        print((hex(A[k][j])[2:]), end=' ')
    print()
print()
# Out:
# Hasil Ciphertext
# ...
# bc b0 77 1d
# 75 c6 a5 e5
# 1d ea 9b f
# 1a 16 a9 ec

# %% [markdown]
# # Dekripsi AES

# %% [markdown]
# <img src="decrypt.jpg">

# %% [markdown]
# # STEP 2 - InvShiftRows

# %%
def inv_shift_rows(s):
    s[1][0], s[1][1], s[1][2], s[1][3] = s[1][3], s[1][0], s[1][1], s[1][2]
    s[2][0], s[2][1], s[2][2], s[2][3] = s[2][2], s[2][3], s[2][0], s[2][1]
    s[3][0], s[3][1], s[3][2], s[3][3] = s[3][1], s[3][2], s[3][3], s[3][0]

# %% [markdown]
# # STEP 1 - InvSubBytes

# %%
def inv_sub_bytes(s):
    for i in range(4):
        for j in range(4):
            s[i][j] = inv_s_box[s[i][j]]

# %%
inv_s_box = (
    
)

# %% [markdown]
# # STEP 3 - MixColoumns

# %%
def invMixColumn(s):
    for i in range(3):
        mixColumn(s)

# %%
print('DEKRIPSI AES')

print('============================')
print('Round 0')
print('============================')
printM(A)
print()
print('Add Round Key')
K = expkey[9]
add_round_key(A, K)
printM(K)
print()
printM(A)
print()
print('Inverse Shift Rows')
inv_shift_rows(A)
print()
print('Inverse Sub Bytes')
inv_sub_bytes(A)
print()

reverse = 8
for i in range(9):
    print('============================')
    print('Round ',i+1)
    print('============================')
    print()
    print('R',i+1,'Step 1 - Add Round Key')
    print('----------------------')
    K = expkey[reverse]
    printM(K)
    print()
    add_round_key(A, K)
    printM(A)
    print()
            
    print('R',i+1,'Step 2 - Inv Mix Column')
    print('----------------------')
    invMixColumn(A)
    printM(A)
    print()
    
    print('R',i+1,'Step 3 - Inv Shift Rows')
    print('----------------------')
    inv_shift_rows(A)
    printM(A)
    print()
    
    
    print('R',i+1,'Step 4 - Inv Sub Bytes')
    print('----------------------')
    inv_sub_bytes(A)
    printM(A)
    print()
    
    reverse -= 1
    
print('============================')
print('Round 10')
print('============================')
printM(A)
print()
print('R 10 Step 4 - Add Round Key')
print('----------------------')
add_round_key(A, originalKey)
printM(A)
print()
# Out:
# DEKRIPSI AES
# ...
# Round 0
# ...
# bc  b0  77  1d
# 75  c6  a5  e5
# 1d  ea  9b  f
# 1a  16  a9  ec
#
# Add Round Key
# ef  88  4d  a5
# 92  ad  3b  56
# 36  7a  41  8
# a8  58  86  4f
#
# 53  38  3a  b8
# e7  6b  9e  b3
# 2b  90  da  7
# b2  4e  2f  a3
#
# Inverse Shift Rows
#
# Inverse Sub Bytes
#
# ...
# Round  1
# ...
#
# R 1 Step 1 - Add Round Key
# ----------------------
# e5  67  c5  e8
# a9  3f  96  6d
# eb  4c  3b  49
# 33  f0  de  c9
#
# b5  11  67  72
# e2  8f  93  b2
# 91  74  30  df
# 85  be  af  f7
#
# R 1 Step 2 - Inv Mix Column
# ----------------------
# 44  b6  4c  e4
# f   fd  ca  0
# e6  7b  cd  82
# ee  64  20  8e
#
# R 1 Step 3 - Inv Shift Rows
# ----------------------
# 44  b6  4c  e4
# 0   f   fd  ca
# cd  82  e6  7b
# 64  20  8e  ee
#
# R 1 Step 4 - Inv Sub Bytes
# ----------------------
# 86  79  5d  ae
# 52  fb  21  10
# 80  11  f5  3
# 8c  54  e6  99
#
# ...
# Round  2
# ...
#
# R 2 Step 1 - Add Round Key
# ----------------------
# f1  82  a2  2d
# e9  96  a9  fb
# 1b  a7  77  72
# ...
