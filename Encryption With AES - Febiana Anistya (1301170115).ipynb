# %% [markdown]
# # Enkripsi AES

# %% [markdown]
# <img src="Steps.jpg">

# %% [markdown]
# <img src="Steps-detailed.jpg">

# %% [markdown]
# Task Tugas Besar
# - melakukan enkripsi AES dengan kunci buatan sendiri dan tabel Mix Column buatan sendiri
# - dikumpulkan saat hari H UAS kemungkinan tanggal 14 Mei 2020

# %% [markdown]
# # Initial Round + STEP 4 - AddRoundKey

# %%
def add_round_key(A, k):
    for i in range(4):
        for j in range(4):
            A[i][j] ^= k[i][j]

# %% [markdown]
# # STEP 1 - SubBytes

# %%
def sub_bytes(s):
    for i in range(4):
        for j in range(4):
            s[i][j] = s_box[s[i][j]]

# %% [markdown]
# # STEP 2 - ShiftRows

# %%
def shift_rows(s):
    s[1][0], s[1][1], s[1][2], s[1][3] = s[1][1], s[1][2], s[1][3], s[1][0]
    s[2][0], s[2][1], s[2][2], s[2][3] = s[2][2], s[2][3], s[2][0], s[2][1]
    s[3][0], s[3][1], s[3][2], s[3][3] = s[3][3], s[3][0], s[3][1], s[3][2]

# %% [markdown]
# # STEP 3 - MixColoumns

# %%
def mixColumn(s):
    matrixCustom = [[0x02, 0x03, 0x01, 0x01],
                    [0x01, 0x02, 0x03, 0x01],
                    [0x01, 0x01, 0x02, 0x03],
                    [0x03, 0x01, 0x01, 0x02]]
    
    hasil = []
    for q in range(4):
        temp = []
        temp.append(s[0][q]) 
        temp.append(s[1][q])
        temp.append(s[2][q])
        temp.append(s[3][q])
        for r in range(4):
            newcol = []
            j = 0
            for i in matrixCustom[r]:
                if i == 2:
                    lmix = list(temp[j])
                    lmix[0] = lmix[1]
                    lmix[1] = lmix[2]
                    lmix[2] = lmix[3]
                    lmix[3] = lmix[4]
                    lmix[4] = lmix[5]
                    lmix[5] = lmix[6]
                    lmix[6] = lmix[7]
                    lmix[7] = '0'
                    o = ''.join(lmix)
                    if temp[j][0] == '1':
                        newcol.append(int(o,2) ^ 0x1b)
                    else:
                        newcol.append(int(o,2))
                elif i == 3:
                    p = int(temp[j],2)
                    lmix = list(temp[j])
                    lmix[0] = lmix[1]
                    lmix[1] = lmix[2]
                    lmix[2] = lmix[3]
                    lmix[3] = lmix[4]
                    lmix[4] = lmix[5]
                    lmix[5] = lmix[6]
                    lmix[6] = lmix[7]
                    lmix[7] = '0'
                    o = ''.join(lmix)
                    if temp[j][0] == '1':
                        newcol.append(int(o,2) ^ 0x1b ^ p)
                    else:
                        newcol.append(int(o,2) ^ p)
                else:
                    newcol.append(int(temp[j],2))
                j += 1
            hasil.append(newcol[0] ^ newcol[1] ^ newcol[2] ^ newcol[3])
    c = 0
    for i in range(4):
        for o in range(4):
            s[o][i] = hasil[c]
            c += 1

# %%
def keySchedule(key, idRound):
    temp = []
    temp.append(key[1][3])
    temp.append(key[2][3])
    temp.append(key[3][3])
    temp.append(key[0][3])

    temp2 = []
    temp2.append(key[0][0])
    temp2.append(key[1][0])
    temp2.append(key[2][0])
    temp2.append(key[3][0])
    
    RCon = [[0x01, 0x00, 0x00, 0x00],
            [0x02, 0x00, 0x00, 0x00],
            [0x04, 0x00, 0x00, 0x00],
            [0x08, 0x00, 0x00, 0x00],
            [0x10, 0x00, 0x00, 0x00],
            [0x20, 0x00, 0x00, 0x00],
            [0x40, 0x00, 0x00, 0x00],
            [0x80, 0x00, 0x00, 0x00],
            [0x1b, 0x00, 0x00, 0x00],
            [0x36, 0x00, 0x00, 0x00]]
    print(idRound, hex(RCon[idRound][0]))
    for i in range(4):
        temp[i] = s_box[temp[i]]

    n = 0
    c1 = []
    for i in temp:
        c1.append(i ^ RCon[idRound][n] ^ temp2[n])
        n += 1
    print(c1)
    c2 = []
    for e in range(4):
        c2.append(key[e][1] ^ c1[e])

    c3 = []
    for e in range(4):
        c3.append(key[e][2] ^ c2[e])

    c4 = []
    for e in range(4):
        c4.append(key[e][3] ^ c3[e])

    newkey = []
    for i in range(4):
        newkey.append([c1[i], c2[i], c3[i], c4[i]])

    c = 0    
    for i in range(4):
        for o in range(4):
            key[o][i] = newkey[o][i]
            c += 1

# %%
ko = [[0x4e, 0x5f, 0x84, 0x4e],
      [0x54, 0x5f, 0xa6, 0xa6],
      [0xf7, 0xc9, 0x4f, 0xdc],
      [0x0e, 0xf3, 0xb2, 0x4f]]
keySchedule(ko, 7)
printM(ko)
# Out:
# 7 0x1b
# [113, 210, 115, 33]
# 71  2e  aa  e4
# d2  8d  2b  8d
# 73  ba  f5  29
# 21  d2  60  2f

# %%
s_box = (
    ,
)

# %% [markdown]
# # PROSES ENKRIPSI

# %%
print(hex(0x32 ^ 0x2b))
# Out:
# 0x19

# %%
def printM(s):
    print('\n'.join([''.join(['{:4}'.format(hex(item)[2:]) for item in row]) 
      for row in s]))

# %%
def printbin(s):
    for r in s:
        print(r)

# %%
print('ENKRIPSI AES')
A = [[0x73, 0x61, 0x79, 0x61],
     [0x73, 0x75, 0x6b, 0x61],
     [0x6d, 0x61, 0x69, 0x6e],
     [0x61, 0x6c, 0x67, 0x6f]]

# A = [[0x32, 0x88, 0x31, 0xe0],
#      [0x43, 0x5a, 0x31, 0x37],
#      [0xf6, 0x30, 0x98, 0x07],
#      [0xa8, 0x8d, 0xa2, 0x34]]

K = [[0x62, 0x75, 0x61, 0x74],
     [0x6b, 0x65, 0x79, 0x73],
     [0x6c, 0x61, 0x67, 0x69],
     [0x64, 0x69, 0x72, 0x69]]

# K = [[0x2b, 0x28, 0xab, 0x09],
#      [0x7e, 0xae, 0xf7, 0xcf],
#      [0x15, 0xd2, 0x15, 0x4f],
#      [0x16, 0xa6, 0x88, 0x3c]]

print('============================')
print('Round 0')
print('============================')
printM(A)
print()
print('Add Round Key')
add_round_key(A, K)
printM(A)
print()

for i in range(9):
    print('============================')
    print('Round ',i+1)
    print('============================')
    print()
    print('R',i+1,'Step 1 - Sub Bytes')
    print('----------------------')
    sub_bytes(A)
    printM(A)
    print()
    shift_rows(A)
    print('R',i+1,'Step 2 - Shift Rows')
    print('----------------------')
    printM(A)
    print(A)
    print()
    for r in range(len(A)):
        for d in range(len(A[r])):
            A[r][d] = bin(A[r][d])[2:].zfill(8)
    print('R',i+1,'Step 3 - Mix Column')
    print('----------------------')
    mixColumn(A)
    printM(A)
    print()
    keySchedule(K, i)
    print('R',i+1,'Step 4 - Add Round Key')
    print('----------------------')
    printM(K)
    print()
    add_round_key(A, K)
    printM(A)
    print()
    
print('============================')
print('Round 10')
print('============================')
printM(A)
print()
print('R 10 Step 1 - Sub Bytes')
print('----------------------')
sub_bytes(A)
printM(A)
print()
print('R 10 Step 2 - Shift Rows')
print('----------------------')
shift_rows(A)
printM(A)
print()
print('R 10 Step 4 - Add Round Key')
print('----------------------')
keySchedule(K,9)
add_round_key(A, K)
printM(A)
print()
# Out:
# ENKRIPSI AES
# ============================
# Round 0
# ============================
# 32  88  31  e0
# 43  5a  31  37
# f6  30  98  7
# a8  8d  a2  34
#
# Add Round Key
# 19  a0  9a  e9
# 3d  f4  c6  f8
# e3  e2  8d  48
# be  2b  2a  8
#
# ============================
# Round  1
# ============================
#
# R 1 Step 1 - Sub Bytes
# ----------------------
# d4  e0  b8  1e
# 27  bf  b4  41
# 11  98  5d  52
# ae  f1  e5  30
#
# R 1 Step 2 - Shift Rows
# ----------------------
# d4  e0  b8  1e
# bf  b4  41  27
# 5d  52  11  98
# 30  ae  f1  e5
# [[212, 224, 184, 30], [191, 180, 65, 39], [93, 82, 17, 152], [48, 174, 241, 229]]
#
# R 1 Step 3 - Mix Column
# ----------------------
# 4   e0  48  28
# 66  cb  f8  6
# 81  19  d3  26
# e5  9a  7a  4c
#
# 0 0x1
# [160, 250, 254, 23]
# R 1 Step 4 - Add Round Key
# ----------------------
# a0  88  23  2a
# fa  54  a3  6c
# fe  2c  39  76
# 17  b1  39  5
#
# a4  68  6b  2
# 9c  9f  5b  6a
# 7f  35  ea  50
# f2  2b  43  49
#
# ============================
# Round  2
# ============================
#
# R 2 Step 1 - Sub Bytes
# ----------------------
# 49  45  7f  77
# de  db  39  2
# d2  96  87  53
# 89  f1  1a  3b
#
# R 2 Step 2 - Shift Rows
# ----------------------
# 49  45  7f  77
# db  39  2   de
# 87  53  d2  96
# 3b  89  f1  1a
# [[73, 69, 127, 119], [219, 57, 2, 222], [135, 83, 210, 150], [59, 137, 241, 26]]
#
# R 2 Step 3 - Mix Column
# ----------------------
# 58  1b  db  1b
# 4d  4b  e7  6b
# ca  5a  ca  b0
# f1  ac  a8  e5
#
# 1 0x2
# [242, 194, 149, 242]
# R 2 Step 4 - Add Round Key
# ----------------------
# f2  7a  59  73
# c2  96  35  59
# 95  b9  80  f6
# f2  43  7a  7f
#
# aa  61  82  68
# 8f  dd  d2  32
# 5f  e3  4a  46
# 3   ef  d2  9a
#
# ============================
# Round  3
# ============================
#
# R 3 Step 1 - Sub Bytes
# ----------------------
# ac  ef  13  45
# 73  c1  b5  23
# cf  11  d6  5a
# 7b  df  b5  b8
#
# R 3 Step 2 - Shift Rows
# ----------------------
# ac  ef  13  45
# c1  b5  23  73
# d6  5a  cf  11
# b8  7b  df  b5
# [[172, 239, 19, 69], [193, 181, 35, 115], [214, 90, 207, 17], [184, 123, 223, 181]]
#
# R 3 Step 3 - Mix Column
# ----------------------
# 75  20  53  bb
# ec  b   c0  25
# 9   63  cf  d0
# 93  33  7c  dc
#
# 2 0x4
# [61, 128, 71, 125]
# R 3 Step 4 - Add Round Key
# ----------------------
# 3d  47  1e  6d
# 80  16  23  7a
# 47  fe  7e  88
# 7d  3e  44  3b
#
# 48  67  4d  d6
# 6c  1d  e3  5f
# 4e  9d  b1  58
# ee  d   38  e7
#
# ============================
# Round  4
# ============================
#
# R 4 Step 1 - Sub Bytes
# ----------------------
# 52  85  e3  f6
# 50  a4  11  cf
# 2f  5e  c8  6a
# 28  d7  7   94
#
# R 4 Step 2 - Shift Rows
# ----------------------
# 52  85  e3  f6
# a4  11  cf  50
# c8  6a  2f  5e
# 94  28  d7  7
# [[82, 133, 227, 246], [164, 17, 207, 80], [200, 106, 47, 94], [148, 40, 215, 7]]
#
# R 4 Step 3 - Mix Column
# ----------------------
# f   60  6f  5e
# d6  31  c0  b3
# da  38  10  13
# a9  bf  6b  1
#
# 3 0x8
# [239, 68, 165, 65]
# R 4 Step 4 - Add Round Key
# ----------------------
# ef  a8  b6  db
# 44  52  71  b
# a5  5b  25  ad
# 41  7f  3b  0
#
# e0  c8  d9  85
# 92  63  b1  b8
# 7f  63  35  be
# e8  c0  50  1
#
# ============================
# Round  5
# ============================
#
# R 5 Step 1 - Sub Bytes
# ----------------------
# e1  e8  35  97
# 4f  fb  c8  6c
# d2  fb  96  ae
# 9b  ba  53  7c
#
# R 5 Step 2 - Shift Rows
# ----------------------
# e1  e8  35  97
# fb  c8  6c  4f
# 96  ae  d2  fb
# 7c  9b  ba  53
# [[225, 232, 53, 151], [251, 200, 108, 79], [150, 174, 210, 251], [124, 155, 186, 83]]
#
# R 5 Step 3 - Mix Column
# ----------------------
# 25  bd  b6  4c
# d1  11  3a  4c
# a9  d1  33  c0
# ad  68  8e  b0
#
# 4 0x10
# [212, 209, 198, 248]
# R 5 Step 4 - Add Round Key
# ----------------------
# d4  7c  ca  11
# d1  83  f2  f9
# c6  9d  b8  15
# f8  87  bc  bc
#
# f1  c1  7c  5d
# 0   92  c8  b5
# 6f  4c  8b  d5
# 55  ef  32  c
#
# ============================
# Round  6
# ============================
#
# R 6 Step 1 - Sub Bytes
# ----------------------
# a1  78  10  4c
# 63  4f  e8  d5
# a8  29  3d  3
# fc  df  23  fe
#
# R 6 Step 2 - Shift Rows
# ----------------------
# a1  78  10  4c
# 4f  e8  d5  63
# 3d  3   a8  29
# fe  fc  df  23
# [[161, 120, 16, 76], [79, 232, 213, 99], [61, 3, 168, 41], [254, 252, 223, 35]]
#
# R 6 Step 3 - Mix Column
# ----------------------
# 4b  2c  33  37
# 86  4a  9d  d2
# 8d  89  f4  18
# 6d  80  e8  d8
#
# 5 0x20
# [109, 136, 163, 122]
# R 6 Step 4 - Add Round Key
# ----------------------
# 6d  11  db  ca
# 88  b   f9  0
# a3  3e  86  93
# 7a  fd  41  fd
#
# 26  3d  e8  fd
# e   41  64  d2
# 2e  b7  72  8b
# 17  7d  a9  25
#
# ============================
# Round  7
# ============================
#
# R 7 Step 1 - Sub Bytes
# ----------------------
# f7  27  9b  54
# ab  83  43  b5
# 31  a9  40  3d
# f0  ff  d3  3f
#
# R 7 Step 2 - Shift Rows
# ----------------------
# f7  27  9b  54
# 83  43  b5  ab
# 40  3d  31  a9
# 3f  f0  ff  d3
# [[247, 39, 155, 84], [131, 67, 181, 171], [64, 61, 49, 169], [63, 240, 255, 211]]
#
# R 7 Step 3 - Mix Column
# ----------------------
# 14  46  27  34
# 15  16  46  2a
# b5  15  56  d8
# bf  ec  d7  43
#
# 6 0x40
# [78, 84, 247, 14]
# R 7 Step 4 - Add Round Key
# ----------------------
# 4e  5f  84  4e
# 54  5f  a6  a6
# f7  c9  4f  dc
# e   f3  b2  4f
#
# 5a  19  a3  7a
# 41  49  e0  8c
# 42  dc  19  4
# b1  1f  65  c
#
# ============================
# Round  8
# ============================
#
# R 8 Step 1 - Sub Bytes
# ----------------------
# be  d4  a   da
# 83  3b  e1  64
# 2c  86  d4  f2
# c8  c0  4d  fe
#
# R 8 Step 2 - Shift Rows
# ----------------------
# be  d4  a   da
# 3b  e1  64  83
# d4  f2  2c  86
# fe  c8  c0  4d
# [[190, 212, 10, 218], [59, 225, 100, 131], [212, 242, 44, 134], [254, 200, 192, 77]]
#
# R 8 Step 3 - Mix Column
# ----------------------
# 0   b1  54  fa
# 51  c8  76  1b
# 2f  89  6d  99
# d1  ff  cd  ea
#
# 7 0x80
# [234, 210, 115, 33]
# R 8 Step 4 - Add Round Key
# ----------------------
# ea  b5  31  7f
# d2  8d  2b  8d
# 73  ba  f5  29
# 21  d2  60  2f
#
# ea  4   65  85
# 83  45  5d  96
# 5c  33  98  b0
# f0  2d  ad  c5
#
# ============================
# Round  9
# ============================
#
# R 9 Step 1 - Sub Bytes
# ----------------------
# 87  f2  4d  97
# ec  6e  4c  90
# 4a  c3  46  e7
# 8c  d8  95  a6
#
# R 9 Step 2 - Shift Rows
# ----------------------
# 87  f2  4d  97
# 6e  4c  90  ec
# 46  e7  4a  c3
# a6  8c  d8  95
# [[135, 242, 77, 151], [110, 76, 144, 236], [70, 231, 74, 195], [166, 140, 216, 149]]
#
# R 9 Step 3 - Mix Column
# ----------------------
# 47  40  a3  4c
# 37  d4  70  9f
# 94  e4  3a  42
# ed  a5  a6  bc
#
# 8 0x1b
# [172, 119, 102, 243]
# R 9 Step 4 - Add Round Key
# ----------------------
# ac  19  28  57
# 77  fa  d1  5c
# 66  dc  29  0
# f3  21  41  6e
#
# eb  59  8b  1b
# 40  2e  a1  c3
# f2  38  13  42
# 1e  84  e7  d2
#
# ============================
# Round 10
# ============================
# eb  59  8b  1b
# 40  2e  a1  c3
# f2  38  13  42
# 1e  84  e7  d2
#
# R 10 Step 1 - Sub Bytes
# ----------------------
# e9  cb  3d  af
# 9   31  32  2e
# 89  7   7d  2c
# 72  5f  94  b5
#
# R 10 Step 2 - Shift Rows
# ----------------------
# e9  cb  3d  af
# 31  32  2e  9
# 7d  2c  89  7
# b5  72  5f  94
#
# R 10 Step 4 - Add Round Key
# ----------------------
# 9 0x36
# [208, 20, 249, 168]
# 39  2   dc  19
# 25  dc  11  6a
# 84  9   85  b
# 1d  fb  97  32

# %% [markdown]
# # Ciphertext

# %%
print('Hasil Ciphertext')
print('============================')
for k in range(4):
    for j in range(4):
        print((hex(A[k][j])[2:]), end=' ')
    print()
print()
# Out:
# Hasil Ciphertext
# ============================
# 39 2 dc 19
# 25 dc 11 6a
# 84 9 85 b
# 1d fb 97 32

# %% [markdown]
# # Dekripsi AES

# %% [markdown]
# <img src="decrypt.jpg">

# %% [markdown]
# # STEP 2 - InvShiftRows

# %%
def shift_rows(s):
    s[1][0], s[1][1], s[1][2], s[1][3] = s[1][3], s[1][0], s[1][1], s[1][2]
    s[2][0], s[2][1], s[2][2], s[2][3] = s[2][2], s[2][3], s[2][0], s[2][1]
    s[3][0], s[3][1], s[3][2], s[3][3] = s[3][1], s[3][2], s[3][3], s[3][0# STEP 1 - SubBytes
# Out:
#   File "<ipython-input-13-a60582bffcde>", line 4
#     s[3][0], s[3][1], s[3][2], s[3][3] = s[3][1], s[3][2], s[3][3], s[3][0# STEP 1 - SubBytes
#                                                                                              ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# # STEP 1 - InvSubBytes

# %%
def sub_bytes(s):
    for i in range(4):
        for j in range(4):
            s[i][j] = inv_s_box[s[i][j]]

# %%
inv_s_box = (
    
)

# %% [markdown]
# # STEP 3 - MixColoumns

# %%
def invMixColumn(s):
    matrixCustom = [[14, 11, 13, 9],
                    [9, 14, 11, 13],
                    [13, 9, 14, 11],
                    [11, 13, 9, 14]]
    for i in range(len(s)):

# %%
print(hex(0x04 ^ 0xa0))
# Out:
# 0xa4
